# %%
import csv
import math
import matplotlib.pyplot as plt 
from svmutil import *
from operator import itemgetter

# %%
data_set_file_path = "data/spambase.data.shuffled.txt"

converted_data_set_file_path = "data/spambase.data.shuffled.converted.txt"

learn_scaled_converted_data_set_file_path = "data/spambase.data.shuffled.converted.learn.scaled.txt"
test_scaled_converted_data_set_file_path = "data/spambase.data.shuffled.converted.test.scaled.txt"

kernel_type = 2

# %%
def learn_k_fold(x, y, folds_count, d_values, C_values):
    assert len(x) == len(y)
    
    results = list()
    fold_size = len(x) // folds_count
    for d in d_values:
        for C in C_values:
            params_string = '-q -t {2} -d {0} -c {1}'.format(d, C, kernel_type)
            
            accuracies = list()
            errors = list()
            for fold in range(folds_count):
                validate_sample_x = x[fold * fold_size : (fold + 1) * fold_size]
                validate_sample_y = y[fold * fold_size : (fold + 1) * fold_size]

                learn_sample_x = x[0 : fold * fold_size] + x[(fold + 1) * fold_size:]
                learn_sample_y = y[0 : fold * fold_size] + y[(fold + 1) * fold_size:]
                
                assert len(validate_sample_x) + len(learn_sample_x) == len(x)
                assert len(validate_sample_y) + len(learn_sample_y) == len(y)
                
                assert len(validate_sample_x) == fold_size
                assert len(validate_sample_y) == fold_size
                
                m = svm_train(learn_sample_y, learn_sample_x, params_string)
                p_label, p_acc, p_val = svm_predict(validate_sample_y, validate_sample_x, m, '-q')
                
                accuracies.append(p_acc[0])
                errors.append(p_acc[1] * 100) # error returned not in percents
                
            
            print("Parameters: ", params_string)
            # Calculate average error
            average_accuracy = sum(accuracies) / folds_count
            print("Cross Validation Accuracy = ", average_accuracy)
            average_error = sum(errors) / folds_count
            print("Cross Validation Error = ", average_error)
            sd = math.sqrt(sum([(average_error - error)**2 for error in errors]) / folds_count)
            print("Standard Deviation = ", sd)
            
            
            # Calculate empirical risk
            m = svm_train(y, x, params_string)
            p_label, p_acc, p_val = svm_predict(y, x, m, '-q')
            empirical_risk = p_acc[1] * 100
            print("Empirical risk = ", empirical_risk)
            
            
            results.append((d, C, average_accuracy, average_error, sd, empirical_risk))
    
    return results

# %%
k = 20

d_values = [1]
C_values = [2**x for x in range(-k, k + 1)]

y, x = svm_read_problem(learn_scaled_converted_data_set_file_path)

k_fold_results = learn_k_fold(x, y, 10, d_values, C_values)
# Out:
# Parameters:  -q -t 2 -d 1 -c 9.5367431640625e-07
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 1.9073486328125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 3.814697265625e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 7.62939453125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 1.52587890625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 3.0517578125e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 6.103515625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.0001220703125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.000244140625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.00048828125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.0009765625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.001953125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.00390625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.0078125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.015625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.03125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.0625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 2 -d 1 -c 0.25
# Cross Validation Accuracy =  60.78260869565217
# Cross Validation Error =  39.21739130434783
# Standard Deviation =  2.615289572975543
# Empirical risk =  39.33333333333333
# Parameters:  -q -t 2 -d 1 -c 0.5
# Cross Validation Accuracy =  64.81159420289856
# Cross Validation Error =  35.18840579710145
# Standard Deviation =  2.315940215123269
# Empirical risk =  31.94202898550725
# Parameters:  -q -t 2 -d 1 -c 1
# Cross Validation Accuracy =  79.8840579710145
# Cross Validation Error =  20.115942028985508
# Standard Deviation =  1.7400963501221605
# Empirical risk =  19.07246376811594
# Parameters:  -q -t 2 -d 1 -c 2
# Cross Validation Accuracy =  83.3913043478261
# Cross Validation Error =  16.608695652173914
# Standard Deviation =  1.9661064211143906
# Empirical risk =  15.855072463768117
# Parameters:  -q -t 2 -d 1 -c 4
# Cross Validation Accuracy =  85.65217391304347
# Cross Validation Error =  14.347826086956525
# Standard Deviation =  1.8525798471043233
# Empirical risk =  14.000000000000002
# Parameters:  -q -t 2 -d 1 -c 8
# Cross Validation Accuracy =  87.59420289855072
# Cross Validation Error =  12.405797101449275
# Standard Deviation =  1.659024698116427
# Empirical risk =  12.144927536231883
# Parameters:  -q -t 2 -d 1 -c 16
# Cross Validation Accuracy =  89.1304347826087
# Cross Validation Error =  10.869565217391303
# Standard Deviation =  1.6255159296011537
# Empirical risk =  10.376811594202898
# Parameters:  -q -t 2 -d 1 -c 32
# Cross Validation Accuracy =  90.52173913043478
# Cross Validation Error =  9.478260869565217
# Standard Deviation =  1.4611110911453404
# Empirical risk =  8.898550724637682
# Parameters:  -q -t 2 -d 1 -c 64
# Cross Validation Accuracy =  91.82608695652175
# Cross Validation Error =  8.173913043478262
# Standard Deviation =  1.5105871560342472
# Empirical risk =  7.82608695652174
# Parameters:  -q -t 2 -d 1 -c 128
# Cross Validation Accuracy =  92.05797101449275
# Cross Validation Error =  7.942028985507247
# Standard Deviation =  1.2379221161775433
# Empirical risk =  7.275362318840579
# Parameters:  -q -t 2 -d 1 -c 256
# Cross Validation Accuracy =  92.69565217391305
# Cross Validation Error =  7.304347826086956
# Standard Deviation =  1.2884701896169777
# Empirical risk =  6.434782608695652
# Parameters:  -q -t 2 -d 1 -c 512
# Cross Validation Accuracy =  93.36231884057972
# Cross Validation Error =  6.637681159420291
# Standard Deviation =  1.0486986965290173
# Empirical risk =  6.115942028985507
# Parameters:  -q -t 2 -d 1 -c 1024
# Cross Validation Accuracy =  93.56521739130436
# Cross Validation Error =  6.434782608695651
# Standard Deviation =  1.0673595733056211
# Empirical risk =  5.884057971014492
# Parameters:  -q -t 2 -d 1 -c 2048
# Cross Validation Accuracy =  93.53623188405797
# Cross Validation Error =  6.463768115942028
# Standard Deviation =  1.2094287562333372
# Empirical risk =  5.768115942028985
# Parameters:  -q -t 2 -d 1 -c 4096
# Cross Validation Accuracy =  93.59420289855073
# Cross Validation Error =  6.405797101449275
# Standard Deviation =  1.2052535006545966
# Empirical risk =  5.6231884057971016
# Parameters:  -q -t 2 -d 1 -c 8192
# Cross Validation Accuracy =  93.71014492753623
# Cross Validation Error =  6.289855072463768
# Standard Deviation =  1.3598497513901335
# Empirical risk =  5.072463768115942
# Parameters:  -q -t 2 -d 1 -c 16384
# Cross Validation Accuracy =  93.97101449275362
# Cross Validation Error =  6.028985507246377
# Standard Deviation =  1.1433671259893343
# Empirical risk =  4.956521739130435
# Parameters:  -q -t 2 -d 1 -c 32768
# Cross Validation Accuracy =  94.0
# Cross Validation Error =  6.0
# Standard Deviation =  1.216355667151147
# Empirical risk =  4.608695652173913
# Parameters:  -q -t 2 -d 1 -c 65536
# Cross Validation Accuracy =  93.71014492753622
# Cross Validation Error =  6.289855072463768
# Standard Deviation =  1.290099309232921
# Empirical risk =  4.492753623188406
# Parameters:  -q -t 2 -d 1 -c 131072
# Cross Validation Accuracy =  93.82608695652173
# Cross Validation Error =  6.173913043478262
# Standard Deviation =  1.230092473850605
# Empirical risk =  4.202898550724638
# Parameters:  -q -t 2 -d 1 -c 262144
# Cross Validation Accuracy =  93.68115942028984
# Cross Validation Error =  6.3188405797101455
# Standard Deviation =  1.1936962482303768
# Empirical risk =  3.768115942028986
# Parameters:  -q -t 2 -d 1 -c 524288
# Cross Validation Accuracy =  93.56521739130434
# Cross Validation Error =  6.434782608695651
# Standard Deviation =  1.2949743712283288
# Empirical risk =  3.3623188405797104
# Parameters:  -q -t 2 -d 1 -c 1048576
# Cross Validation Accuracy =  93.18840579710144
# Cross Validation Error =  6.81159420289855
# Standard Deviation =  1.3976305450714428
# Empirical risk =  3.1594202898550723

# %%
for d_value in d_values:
    d_results = [(d, C, average_accuracy, average_error, sd, empirical_risk) for d, C, average_accuracy, average_error, sd, empirical_risk in k_fold_results if d == d_value]
    k_values = [math.log(d_result[1], 2) for d_result in d_results]
    error_values = [d_result[3] for d_result in d_results]
    error_values_with_sd = [d_result[3] + d_result[4] for d_result in d_results]
    error_values_without_sd = [d_result[3] - d_result[4] for d_result in d_results]

    print("d = ", d_value)
    plt.plot(C_values, error_values, 'b', label = "CV error")
    plt.plot(C_values, error_values_without_sd, 'r', label = "CV error - standard deviation") 
    plt.plot(C_values, error_values_with_sd, 'g', label = "CV error + standard deviation")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("С Value")
    plt.ylabel("Сross validation error +/- stadard deviation, %")
    plt.show()
    
    plt.plot(k_values, error_values, 'b', label = "CV error")
    plt.plot(k_values, error_values_without_sd, 'r', label = "CV error - standard deviation") 
    plt.plot(k_values, error_values_with_sd, 'g', label = "CV error + standard deviation")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("log2C Value")
    plt.ylabel("Сross validation error +/- stadard deviation, %")
    plt.show()
    
    risks = [d_result[5] for d_result in d_results]
    
    plt.plot(C_values, risks, 'r')
    plt.xlabel("С Value")
    plt.ylabel("Empirical risk, %")
    plt.show()
    
    plt.plot(k_values, risks, 'r')
    plt.xlabel("log2C Value")
    plt.ylabel("Empirical risk, %")
    plt.show()
# Out:
# d =  1
