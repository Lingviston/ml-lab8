# %%
import csv
import math
import matplotlib.pyplot as plt 
from svmutil import *
from operator import itemgetter

# %%
data_set_file_path = "data/spambase.data.shuffled.txt"

converted_data_set_file_path = "data/spambase.data.shuffled.converted.txt"

learn_scaled_converted_data_set_file_path = "data/spambase.data.shuffled.converted.learn.scaled.txt"
test_scaled_converted_data_set_file_path = "data/spambase.data.shuffled.converted.test.scaled.txt"

kernel_type = 0

# %%
def learn_k_fold(x, y, folds_count, d_values, C_values):
    assert len(x) == len(y)
    
    results = list()
    fold_size = len(x) // folds_count
    for d in d_values:
        for C in C_values:
            params_string = '-q -t {2} -d {0} -c {1}'.format(d, C, kernel_type)
            
            accuracies = list()
            errors = list()
            for fold in range(folds_count):
                validate_sample_x = x[fold * fold_size : (fold + 1) * fold_size]
                validate_sample_y = y[fold * fold_size : (fold + 1) * fold_size]

                learn_sample_x = x[0 : fold * fold_size] + x[(fold + 1) * fold_size:]
                learn_sample_y = y[0 : fold * fold_size] + y[(fold + 1) * fold_size:]
                
                assert len(validate_sample_x) + len(learn_sample_x) == len(x)
                assert len(validate_sample_y) + len(learn_sample_y) == len(y)
                
                assert len(validate_sample_x) == fold_size
                assert len(validate_sample_y) == fold_size
                
                m = svm_train(learn_sample_y, learn_sample_x, params_string)
                p_label, p_acc, p_val = svm_predict(validate_sample_y, validate_sample_x, m, '-q')
                
                accuracies.append(p_acc[0])
                errors.append(p_acc[1] * 100) # error returned not in percents
                
            
            print("Parameters: ", params_string)
            # Calculate average error
            average_accuracy = sum(accuracies) / folds_count
            print("Cross Validation Accuracy = ", average_accuracy)
            average_error = sum(errors) / folds_count
            print("Cross Validation Error = ", average_error)
            sd = math.sqrt(sum([(average_error - error)**2 for error in errors]) / folds_count)
            print("Standard Deviation = ", sd)
            
            
            # Calculate empirical risk
            m = svm_train(y, x, params_string)
            p_label, p_acc, p_val = svm_predict(y, x, m, '-q')
            empirical_risk = p_acc[1] * 100
            print("Empirical risk = ", empirical_risk)
            
            
            results.append((d, C, average_accuracy, average_error, sd, empirical_risk))
    
    return results

# %%
k = 20

d_values = [1]
C_values = [2**x for x in range(-k, k + 1)]

y, x = svm_read_problem(learn_scaled_converted_data_set_file_path)

k_fold_results = learn_k_fold(x, y, 10, d_values, C_values)
# Out:
# Parameters:  -q -t 0 -d 1 -c 9.5367431640625e-07
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 1.9073486328125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 3.814697265625e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 7.62939453125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 1.52587890625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 3.0517578125e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 6.103515625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 0.0001220703125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 0.000244140625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 0.00048828125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 0.0009765625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 0.001953125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 0.00390625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 0 -d 1 -c 0.0078125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.18840579710145
# Parameters:  -q -t 0 -d 1 -c 0.015625
# Cross Validation Accuracy =  62.60869565217392
# Cross Validation Error =  37.391304347826086
# Standard Deviation =  2.6119142785087104
# Empirical risk =  35.391304347826086
# Parameters:  -q -t 0 -d 1 -c 0.03125
# Cross Validation Accuracy =  78.89855072463769
# Cross Validation Error =  21.101449275362324
# Standard Deviation =  2.2962669356914036
# Empirical risk =  19.884057971014492
# Parameters:  -q -t 0 -d 1 -c 0.0625
# Cross Validation Accuracy =  83.18840579710145
# Cross Validation Error =  16.81159420289855
# Standard Deviation =  1.85144573016479
# Empirical risk =  16.492753623188406
# Parameters:  -q -t 0 -d 1 -c 0.125
# Cross Validation Accuracy =  85.5072463768116
# Cross Validation Error =  14.492753623188406
# Standard Deviation =  1.6498839966095884
# Empirical risk =  14.115942028985506
# Parameters:  -q -t 0 -d 1 -c 0.25
# Cross Validation Accuracy =  87.21739130434783
# Cross Validation Error =  12.782608695652172
# Standard Deviation =  1.8029358307343752
# Empirical risk =  12.318840579710146
# Parameters:  -q -t 0 -d 1 -c 0.5
# Cross Validation Accuracy =  88.92753623188405
# Cross Validation Error =  11.072463768115941
# Standard Deviation =  1.5970988190093807
# Empirical risk =  10.782608695652174
# Parameters:  -q -t 0 -d 1 -c 1
# Cross Validation Accuracy =  89.94202898550725
# Cross Validation Error =  10.057971014492754
# Standard Deviation =  1.2504147600071296
# Empirical risk =  9.507246376811594
# Parameters:  -q -t 0 -d 1 -c 2
# Cross Validation Accuracy =  91.39130434782608
# Cross Validation Error =  8.608695652173912
# Standard Deviation =  1.2504147600071298
# Empirical risk =  8.17391304347826
# Parameters:  -q -t 0 -d 1 -c 4
# Cross Validation Accuracy =  91.94202898550722
# Cross Validation Error =  8.057971014492754
# Standard Deviation =  1.499422279000297
# Empirical risk =  7.652173913043478
# Parameters:  -q -t 0 -d 1 -c 8
# Cross Validation Accuracy =  92.1449275362319
# Cross Validation Error =  7.855072463768117
# Standard Deviation =  1.2796371046170503
# Empirical risk =  7.0724637681159415
# Parameters:  -q -t 0 -d 1 -c 16
# Cross Validation Accuracy =  92.66666666666666
# Cross Validation Error =  7.333333333333334
# Standard Deviation =  1.0693256084461866
# Empirical risk =  6.956521739130435
# Parameters:  -q -t 0 -d 1 -c 32
# Cross Validation Accuracy =  92.8695652173913
# Cross Validation Error =  7.130434782608697
# Standard Deviation =  1.2779946484086147
# Empirical risk =  6.173913043478261
# Parameters:  -q -t 0 -d 1 -c 64
# Cross Validation Accuracy =  93.07246376811592
# Cross Validation Error =  6.927536231884059
# Standard Deviation =  1.36231884057971
# Empirical risk =  5.971014492753623
# Parameters:  -q -t 0 -d 1 -c 128
# Cross Validation Accuracy =  93.07246376811592
# Cross Validation Error =  6.927536231884059
# Standard Deviation =  1.1554279088692607
# Empirical risk =  5.942028985507246
# Parameters:  -q -t 0 -d 1 -c 256
# Cross Validation Accuracy =  93.21739130434783
# Cross Validation Error =  6.782608695652174
# Standard Deviation =  1.182381336485283
# Empirical risk =  5.942028985507246
# Parameters:  -q -t 0 -d 1 -c 512
# Cross Validation Accuracy =  93.07246376811595
# Cross Validation Error =  6.927536231884058
# Standard Deviation =  1.3056354353107484
# Empirical risk =  6.173913043478261
# Parameters:  -q -t 0 -d 1 -c 1024
# Cross Validation Accuracy =  92.9855072463768
# Cross Validation Error =  7.014492753623189
# Standard Deviation =  1.1936962482303768
# Empirical risk =  5.971014492753623
# Parameters:  -q -t 0 -d 1 -c 2048
# Cross Validation Accuracy =  92.95652173913042
# Cross Validation Error =  7.043478260869565
# Standard Deviation =  1.0693256084461866
# Empirical risk =  6.086956521739131
# Parameters:  -q -t 0 -d 1 -c 4096
# Cross Validation Accuracy =  93.01449275362317
# Cross Validation Error =  6.985507246376812
# Standard Deviation =  1.0880188045868673
# Empirical risk =  6.057971014492754
# Parameters:  -q -t 0 -d 1 -c 8192
# Cross Validation Accuracy =  93.10144927536233
# Cross Validation Error =  6.898550724637682
# Standard Deviation =  1.1723912125308225
# Empirical risk =  6.028985507246377
# Parameters:  -q -t 0 -d 1 -c 16384
# Cross Validation Accuracy =  93.13043478260869
# Cross Validation Error =  6.869565217391305
# Standard Deviation =  1.2900993092329207
# Empirical risk =  6.086956521739131
# Parameters:  -q -t 0 -d 1 -c 32768
# Cross Validation Accuracy =  93.10144927536231
# Cross Validation Error =  6.898550724637682
# Standard Deviation =  1.288470189616978
# Empirical risk =  6.173913043478261
# Parameters:  -q -t 0 -d 1 -c 65536
# Cross Validation Accuracy =  93.01449275362317
# Cross Validation Error =  6.985507246376812
# Standard Deviation =  1.125966643452466
# Empirical risk =  6.289855072463768
# Parameters:  -q -t 0 -d 1 -c 131072
# Cross Validation Accuracy =  91.44927536231884
# Cross Validation Error =  8.55072463768116
# Standard Deviation =  2.2386496364811164
# Empirical risk =  7.6231884057971016
# Parameters:  -q -t 0 -d 1 -c 262144
# Cross Validation Accuracy =  92.95652173913045
# Cross Validation Error =  7.043478260869565
# Standard Deviation =  1.181315007090715
# Empirical risk =  6.434782608695652
# Parameters:  -q -t 0 -d 1 -c 524288
# Cross Validation Accuracy =  93.15942028985506
# Cross Validation Error =  6.840579710144928
# Standard Deviation =  1.379174174303805
# Empirical risk =  6.405797101449276
# Parameters:  -q -t 0 -d 1 -c 1048576
# Cross Validation Accuracy =  91.15942028985508
# Cross Validation Error =  8.840579710144928
# Standard Deviation =  3.0434782608695645
# Empirical risk =  7.82608695652174

# %%
for d_value in d_values:
    d_results = [(d, C, average_accuracy, average_error, sd, empirical_risk) for d, C, average_accuracy, average_error, sd, empirical_risk in k_fold_results if d == d_value]
    k_values = [math.log(d_result[1], 2) for d_result in d_results]
    error_values = [d_result[3] for d_result in d_results]
    error_values_with_sd = [d_result[3] + d_result[4] for d_result in d_results]
    error_values_without_sd = [d_result[3] - d_result[4] for d_result in d_results]

    print("d = ", d_value)
    plt.plot(C_values, error_values, 'b', label = "CV error")
    plt.plot(C_values, error_values_without_sd, 'r', label = "CV error - standard deviation") 
    plt.plot(C_values, error_values_with_sd, 'g', label = "CV error + standard deviation")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("С Value")
    plt.ylabel("Сross validation error +/- stadard deviation, %")
    plt.show()
    
    plt.plot(k_values, error_values, 'b', label = "CV error")
    plt.plot(k_values, error_values_without_sd, 'r', label = "CV error - standard deviation") 
    plt.plot(k_values, error_values_with_sd, 'g', label = "CV error + standard deviation")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("log2C Value")
    plt.ylabel("Сross validation error +/- stadard deviation, %")
    plt.show()
    
    risks = [d_result[5] for d_result in d_results]
    
    plt.plot(C_values, risks, 'r')
    plt.xlabel("С Value")
    plt.ylabel("Empirical risk, %")
    plt.show()
    
    plt.plot(k_values, risks, 'r')
    plt.xlabel("log2C Value")
    plt.ylabel("Empirical risk, %")
    plt.show()
# Out:
# d =  1
