# %%
import csv
import math
import matplotlib.pyplot as plt 
from svmutil import *
from operator import itemgetter

# %%
data_set_file_path = "data/spambase.data.shuffled.txt"

converted_data_set_file_path = "data/spambase.data.shuffled.converted.txt"

learn_scaled_converted_data_set_file_path = "data/spambase.data.shuffled.converted.learn.scaled.txt"
test_scaled_converted_data_set_file_path = "data/spambase.data.shuffled.converted.test.scaled.txt"

kernel_type = 3

# %%
def learn_k_fold(x, y, folds_count, d_values, C_values):
    assert len(x) == len(y)
    
    results = list()
    fold_size = len(x) // folds_count
    for d in d_values:
        for C in C_values:
            params_string = '-q -t {2} -d {0} -c {1}'.format(d, C, kernel_type)
            
            accuracies = list()
            errors = list()
            for fold in range(folds_count):
                validate_sample_x = x[fold * fold_size : (fold + 1) * fold_size]
                validate_sample_y = y[fold * fold_size : (fold + 1) * fold_size]

                learn_sample_x = x[0 : fold * fold_size] + x[(fold + 1) * fold_size:]
                learn_sample_y = y[0 : fold * fold_size] + y[(fold + 1) * fold_size:]
                
                assert len(validate_sample_x) + len(learn_sample_x) == len(x)
                assert len(validate_sample_y) + len(learn_sample_y) == len(y)
                
                assert len(validate_sample_x) == fold_size
                assert len(validate_sample_y) == fold_size
                
                m = svm_train(learn_sample_y, learn_sample_x, params_string)
                p_label, p_acc, p_val = svm_predict(validate_sample_y, validate_sample_x, m, '-q')
                
                accuracies.append(p_acc[0])
                errors.append(p_acc[1] * 100) # error returned not in percents
                
            
            print("Parameters: ", params_string)
            # Calculate average error
            average_accuracy = sum(accuracies) / folds_count
            print("Cross Validation Accuracy = ", average_accuracy)
            average_error = sum(errors) / folds_count
            print("Cross Validation Error = ", average_error)
            sd = math.sqrt(sum([(average_error - error)**2 for error in errors]) / folds_count)
            print("Standard Deviation = ", sd)
            
            
            # Calculate empirical risk
            m = svm_train(y, x, params_string)
            p_label, p_acc, p_val = svm_predict(y, x, m, '-q')
            empirical_risk = p_acc[1] * 100
            print("Empirical risk = ", empirical_risk)
            
            
            results.append((d, C, average_accuracy, average_error, sd, empirical_risk))
    
    return results

# %%
k = 20

d_values = [1]
C_values = [2**x for x in range(-k, k + 1)]

y, x = svm_read_problem(learn_scaled_converted_data_set_file_path)

k_fold_results = learn_k_fold(x, y, 10, d_values, C_values)
# Out:
# Parameters:  -q -t 3 -d 1 -c 9.5367431640625e-07
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 1.9073486328125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 3.814697265625e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 7.62939453125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 1.52587890625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 3.0517578125e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 6.103515625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.0001220703125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.000244140625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.00048828125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.0009765625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.001953125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.00390625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.0078125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.015625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.03125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.0625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 3 -d 1 -c 0.25
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.2463768115942
# Parameters:  -q -t 3 -d 1 -c 0.5
# Cross Validation Accuracy =  61.07246376811595
# Cross Validation Error =  38.92753623188407
# Standard Deviation =  2.6975215584469514
# Empirical risk =  38.14492753623188
# Parameters:  -q -t 3 -d 1 -c 1
# Cross Validation Accuracy =  76.08695652173913
# Cross Validation Error =  23.913043478260875
# Standard Deviation =  2.7779248018221927
# Empirical risk =  22.057971014492754
# Parameters:  -q -t 3 -d 1 -c 2
# Cross Validation Accuracy =  82.43478260869566
# Cross Validation Error =  17.56521739130435
# Standard Deviation =  1.5238770351414395
# Empirical risk =  17.101449275362317
# Parameters:  -q -t 3 -d 1 -c 4
# Cross Validation Accuracy =  84.78260869565217
# Cross Validation Error =  15.217391304347828
# Standard Deviation =  1.7160301583322533
# Empirical risk =  14.695652173913043
# Parameters:  -q -t 3 -d 1 -c 8
# Cross Validation Accuracy =  86.92753623188405
# Cross Validation Error =  13.072463768115943
# Standard Deviation =  1.8804871400937502
# Empirical risk =  12.579710144927535
# Parameters:  -q -t 3 -d 1 -c 16
# Cross Validation Accuracy =  88.66666666666667
# Cross Validation Error =  11.333333333333334
# Standard Deviation =  1.858013972236214
# Empirical risk =  10.753623188405797
# Parameters:  -q -t 3 -d 1 -c 32
# Cross Validation Accuracy =  89.91304347826086
# Cross Validation Error =  10.086956521739129
# Standard Deviation =  1.4188102319443958
# Empirical risk =  9.304347826086957
# Parameters:  -q -t 3 -d 1 -c 64
# Cross Validation Accuracy =  90.92753623188405
# Cross Validation Error =  9.072463768115943
# Standard Deviation =  1.624481886284296
# Empirical risk =  8.579710144927537
# Parameters:  -q -t 3 -d 1 -c 128
# Cross Validation Accuracy =  91.1014492753623
# Cross Validation Error =  8.898550724637682
# Standard Deviation =  1.5878661941799814
# Empirical risk =  8.289855072463768
# Parameters:  -q -t 3 -d 1 -c 256
# Cross Validation Accuracy =  89.01449275362317
# Cross Validation Error =  10.98550724637681
# Standard Deviation =  1.552552085894734
# Empirical risk =  10.492753623188406
# Parameters:  -q -t 3 -d 1 -c 512
# Cross Validation Accuracy =  87.91304347826089
# Cross Validation Error =  12.08695652173913
# Standard Deviation =  1.5285561592388648
# Empirical risk =  11.36231884057971
# Parameters:  -q -t 3 -d 1 -c 1024
# Cross Validation Accuracy =  87.15942028985509
# Cross Validation Error =  12.840579710144928
# Standard Deviation =  1.6903795144143
# Empirical risk =  11.797101449275363
# Parameters:  -q -t 3 -d 1 -c 2048
# Cross Validation Accuracy =  86.86956521739131
# Cross Validation Error =  13.130434782608697
# Standard Deviation =  1.472566469087599
# Empirical risk =  12.086956521739129
# Parameters:  -q -t 3 -d 1 -c 4096
# Cross Validation Accuracy =  86.55072463768116
# Cross Validation Error =  13.44927536231884
# Standard Deviation =  1.3104527020820071
# Empirical risk =  12.0
# Parameters:  -q -t 3 -d 1 -c 8192
# Cross Validation Accuracy =  86.57971014492753
# Cross Validation Error =  13.420289855072463
# Standard Deviation =  1.35365732508239
# Empirical risk =  12.115942028985508
# Parameters:  -q -t 3 -d 1 -c 16384
# Cross Validation Accuracy =  86.31884057971016
# Cross Validation Error =  13.681159420289854
# Standard Deviation =  1.333333333333333
# Empirical risk =  12.202898550724637
# Parameters:  -q -t 3 -d 1 -c 32768
# Cross Validation Accuracy =  86.31884057971016
# Cross Validation Error =  13.681159420289854
# Standard Deviation =  1.382824399058152
# Empirical risk =  12.289855072463768
# Parameters:  -q -t 3 -d 1 -c 65536
# Cross Validation Accuracy =  86.40579710144928
# Cross Validation Error =  13.594202898550723
# Standard Deviation =  1.4107934520159948
# Empirical risk =  11.884057971014492
# Parameters:  -q -t 3 -d 1 -c 131072
# Cross Validation Accuracy =  86.46376811594203
# Cross Validation Error =  13.536231884057969
# Standard Deviation =  1.4839334186864002
# Empirical risk =  11.971014492753623
# Parameters:  -q -t 3 -d 1 -c 262144
# Cross Validation Accuracy =  86.40579710144928
# Cross Validation Error =  13.594202898550723
# Standard Deviation =  1.4691392344897605
# Empirical risk =  11.971014492753623
# Parameters:  -q -t 3 -d 1 -c 524288
# Cross Validation Accuracy =  86.34782608695653
# Cross Validation Error =  13.652173913043475
# Standard Deviation =  1.3499282344573929
# Empirical risk =  11.971014492753623
# Parameters:  -q -t 3 -d 1 -c 1048576
# Cross Validation Accuracy =  86.46376811594203
# Cross Validation Error =  13.536231884057969
# Standard Deviation =  1.4839334186864002
# Empirical risk =  11.971014492753623

# %%
for d_value in d_values:
    d_results = [(d, C, average_accuracy, average_error, sd, empirical_risk) for d, C, average_accuracy, average_error, sd, empirical_risk in k_fold_results if d == d_value]
    k_values = [math.log(d_result[1], 2) for d_result in d_results]
    error_values = [d_result[3] for d_result in d_results]
    error_values_with_sd = [d_result[3] + d_result[4] for d_result in d_results]
    error_values_without_sd = [d_result[3] - d_result[4] for d_result in d_results]

    print("d = ", d_value)
    plt.plot(C_values, error_values, 'b', label = "CV error")
    plt.plot(C_values, error_values_without_sd, 'r', label = "CV error - standard deviation") 
    plt.plot(C_values, error_values_with_sd, 'g', label = "CV error + standard deviation")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("С Value")
    plt.ylabel("Сross validation error +/- stadard deviation, %")
    plt.show()
    
    plt.plot(k_values, error_values, 'b', label = "CV error")
    plt.plot(k_values, error_values_without_sd, 'r', label = "CV error - standard deviation") 
    plt.plot(k_values, error_values_with_sd, 'g', label = "CV error + standard deviation")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("log2C Value")
    plt.ylabel("Сross validation error +/- stadard deviation, %")
    plt.show()
    
    risks = [d_result[5] for d_result in d_results]
    
    plt.plot(C_values, risks, 'r')
    plt.xlabel("С Value")
    plt.ylabel("Empirical risk, %")
    plt.show()
    
    plt.plot(k_values, risks, 'r')
    plt.xlabel("log2C Value")
    plt.ylabel("Empirical risk, %")
    plt.show()
# Out:
# d =  1
