# %%
import csv
import math
import matplotlib.pyplot as plt 
from svmutil import *
from operator import itemgetter

# %%
data_set_file_path = "data/spambase.data.shuffled.txt"

converted_data_set_file_path = "data/spambase.data.shuffled.converted.txt"

learn_scaled_converted_data_set_file_path = "data/spambase.data.shuffled.converted.learn.scaled.txt"
test_scaled_converted_data_set_file_path = "data/spambase.data.shuffled.converted.test.scaled.txt"

# %%
def learn_k_fold(x, y, folds_count, d_values, C_values):
    assert len(x) == len(y)
    
    results = list()
    fold_size = len(x) // folds_count
    for d in d_values:
        for C in C_values:
            params_string = '-q -t 1 -d {0} -c {1}'.format(d, C)
            
            accuracies = list()
            errors = list()
            for fold in range(folds_count):
                validate_sample_x = x[fold * fold_size : (fold + 1) * fold_size]
                validate_sample_y = y[fold * fold_size : (fold + 1) * fold_size]

                learn_sample_x = x[0 : fold * fold_size] + x[(fold + 1) * fold_size:]
                learn_sample_y = y[0 : fold * fold_size] + y[(fold + 1) * fold_size:]
                
                assert len(validate_sample_x) + len(learn_sample_x) == len(x)
                assert len(validate_sample_y) + len(learn_sample_y) == len(y)
                
                assert len(validate_sample_x) == fold_size
                assert len(validate_sample_y) == fold_size
                
                m = svm_train(learn_sample_y, learn_sample_x, params_string)
                p_label, p_acc, p_val = svm_predict(validate_sample_y, validate_sample_x, m, '-q')
                
                accuracies.append(p_acc[0])
                errors.append(p_acc[1] * 100) # error returned not in percents
                
            
            print("Parameters: ", params_string)
            # Calculate average error
            average_accuracy = sum(accuracies) / folds_count
            print("Cross Validation Accuracy = ", average_accuracy)
            average_error = sum(errors) / folds_count
            print("Cross Validation Error = ", average_error)
            sd = math.sqrt(sum([(average_error - error)**2 for error in errors]) / folds_count)
            print("Standard Deviation = ", sd)
            
            
            # Calculate empirical risk
            m = svm_train(y, x, params_string)
            p_label, p_acc, p_val = svm_predict(y, x, m, '-q')
            empirical_risk = p_acc[1] * 100
            print("Empirical risk = ", empirical_risk)
            
            
            results.append((d, C, average_accuracy, average_error, sd, empirical_risk))
    
    return results

# %%
k = 20

d_values = range(1, 5)
C_values = [2**x for x in range(-k, k + 1)]

y, x = svm_read_problem(learn_scaled_converted_data_set_file_path)

k_fold_results = learn_k_fold(x, y, 10, d_values, C_values)
# Out:
# Parameters:  -q -t 1 -d 1 -c 9.5367431640625e-07
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 1.9073486328125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 3.814697265625e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 7.62939453125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 1.52587890625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 3.0517578125e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 6.103515625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.0001220703125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.000244140625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.00048828125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.0009765625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.001953125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.00390625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.0078125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.015625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.03125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.0625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.125
# Cross Validation Accuracy =  60.78260869565217
# Cross Validation Error =  39.21739130434783
# Standard Deviation =  2.615289572975543
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 1 -c 0.25
# Cross Validation Accuracy =  64.86956521739131
# Cross Validation Error =  35.130434782608695
# Standard Deviation =  2.318115828768953
# Empirical risk =  32.028985507246375
# Parameters:  -q -t 1 -d 1 -c 0.5
# Cross Validation Accuracy =  79.85507246376812
# Cross Validation Error =  20.144927536231886
# Standard Deviation =  1.7306556798293542
# Empirical risk =  19.07246376811594
# Parameters:  -q -t 1 -d 1 -c 1
# Cross Validation Accuracy =  83.33333333333333
# Cross Validation Error =  16.666666666666664
# Standard Deviation =  1.979733485974398
# Empirical risk =  15.884057971014492
# Parameters:  -q -t 1 -d 1 -c 2
# Cross Validation Accuracy =  85.59420289855072
# Cross Validation Error =  14.405797101449277
# Standard Deviation =  1.8876220469756446
# Empirical risk =  14.028985507246377
# Parameters:  -q -t 1 -d 1 -c 4
# Cross Validation Accuracy =  87.47826086956522
# Cross Validation Error =  12.521739130434785
# Standard Deviation =  1.6128032166079482
# Empirical risk =  12.057971014492754
# Parameters:  -q -t 1 -d 1 -c 8
# Cross Validation Accuracy =  88.98550724637681
# Cross Validation Error =  11.014492753623186
# Standard Deviation =  1.6033990360509365
# Empirical risk =  10.492753623188406
# Parameters:  -q -t 1 -d 1 -c 16
# Cross Validation Accuracy =  90.28985507246378
# Cross Validation Error =  9.710144927536232
# Standard Deviation =  1.4850653283999415
# Empirical risk =  9.130434782608695
# Parameters:  -q -t 1 -d 1 -c 32
# Cross Validation Accuracy =  91.62318840579712
# Cross Validation Error =  8.376811594202898
# Standard Deviation =  1.3684720735203333
# Empirical risk =  7.971014492753622
# Parameters:  -q -t 1 -d 1 -c 64
# Cross Validation Accuracy =  91.94202898550724
# Cross Validation Error =  8.057971014492754
# Standard Deviation =  1.3333333333333335
# Empirical risk =  7.565217391304348
# Parameters:  -q -t 1 -d 1 -c 128
# Cross Validation Accuracy =  92.20289855072465
# Cross Validation Error =  7.797101449275364
# Standard Deviation =  1.2796371046170505
# Empirical risk =  7.043478260869565
# Parameters:  -q -t 1 -d 1 -c 256
# Cross Validation Accuracy =  92.55072463768116
# Cross Validation Error =  7.449275362318842
# Standard Deviation =  1.2024619427647267
# Empirical risk =  6.898550724637681
# Parameters:  -q -t 1 -d 1 -c 512
# Cross Validation Accuracy =  92.86956521739131
# Cross Validation Error =  7.130434782608695
# Standard Deviation =  1.3168483120696288
# Empirical risk =  6.144927536231884
# Parameters:  -q -t 1 -d 1 -c 1024
# Cross Validation Accuracy =  93.13043478260869
# Cross Validation Error =  6.869565217391305
# Standard Deviation =  1.2163556671511466
# Empirical risk =  5.942028985507246
# Parameters:  -q -t 1 -d 1 -c 2048
# Cross Validation Accuracy =  93.10144927536233
# Cross Validation Error =  6.898550724637682
# Standard Deviation =  1.1506917821031424
# Empirical risk =  5.942028985507246
# Parameters:  -q -t 1 -d 1 -c 4096
# Cross Validation Accuracy =  93.18840579710145
# Cross Validation Error =  6.81159420289855
# Standard Deviation =  1.1466690112957958
# Empirical risk =  6.0
# Parameters:  -q -t 1 -d 1 -c 8192
# Cross Validation Accuracy =  93.04347826086956
# Cross Validation Error =  6.956521739130435
# Standard Deviation =  1.3091698307984014
# Empirical risk =  6.057971014492754
# Parameters:  -q -t 1 -d 1 -c 16384
# Cross Validation Accuracy =  92.92753623188405
# Cross Validation Error =  7.072463768115942
# Standard Deviation =  1.1166005961888823
# Empirical risk =  6.086956521739131
# Parameters:  -q -t 1 -d 1 -c 32768
# Cross Validation Accuracy =  92.95652173913042
# Cross Validation Error =  7.043478260869565
# Standard Deviation =  1.037422038734683
# Empirical risk =  6.144927536231884
# Parameters:  -q -t 1 -d 1 -c 65536
# Cross Validation Accuracy =  92.92753623188405
# Cross Validation Error =  7.072463768115942
# Standard Deviation =  1.0783232021877263
# Empirical risk =  6.028985507246377
# Parameters:  -q -t 1 -d 1 -c 131072
# Cross Validation Accuracy =  92.98550724637681
# Cross Validation Error =  7.014492753623189
# Standard Deviation =  1.3396197111062427
# Empirical risk =  6.115942028985507
# Parameters:  -q -t 1 -d 1 -c 262144
# Cross Validation Accuracy =  92.98550724637681
# Cross Validation Error =  7.014492753623188
# Standard Deviation =  1.4938085480261016
# Empirical risk =  6.057971014492754
# Parameters:  -q -t 1 -d 1 -c 524288
# Cross Validation Accuracy =  92.89855072463767
# Cross Validation Error =  7.10144927536232
# Standard Deviation =  1.2246162419871076
# Empirical risk =  6.144927536231884
# Parameters:  -q -t 1 -d 1 -c 1048576
# Cross Validation Accuracy =  92.9855072463768
# Cross Validation Error =  7.014492753623189
# Standard Deviation =  1.1795356492391773
# Empirical risk =  6.0
# Parameters:  -q -t 1 -d 2 -c 9.5367431640625e-07
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 1.9073486328125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 3.814697265625e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 7.62939453125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 1.52587890625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 3.0517578125e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 6.103515625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 0.0001220703125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 0.000244140625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 0.00048828125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 0.0009765625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 0.001953125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 0.00390625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 0.0078125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 0.015625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 0.03125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 2 -c 0.0625
# Cross Validation Accuracy =  60.78260869565217
# Cross Validation Error =  39.21739130434783
# Standard Deviation =  2.615289572975543
# Empirical risk =  39.2463768115942
# Parameters:  -q -t 1 -d 2 -c 0.125
# Cross Validation Accuracy =  65.91304347826086
# Cross Validation Error =  34.086956521739125
# Standard Deviation =  2.134719146611243
# Empirical risk =  31.2463768115942
# Parameters:  -q -t 1 -d 2 -c 0.25
# Cross Validation Accuracy =  80.08695652173914
# Cross Validation Error =  19.91304347826087
# Standard Deviation =  1.8786991794897165
# Empirical risk =  18.927536231884055
# Parameters:  -q -t 1 -d 2 -c 0.5
# Cross Validation Accuracy =  83.36231884057972
# Cross Validation Error =  16.63768115942029
# Standard Deviation =  1.9795212845175505
# Empirical risk =  15.971014492753625
# Parameters:  -q -t 1 -d 2 -c 1
# Cross Validation Accuracy =  85.53623188405797
# Cross Validation Error =  14.463768115942031
# Standard Deviation =  1.876014043511235
# Empirical risk =  14.028985507246377
# Parameters:  -q -t 1 -d 2 -c 2
# Cross Validation Accuracy =  87.59420289855072
# Cross Validation Error =  12.405797101449275
# Standard Deviation =  1.6128032166079485
# Empirical risk =  12.26086956521739
# Parameters:  -q -t 1 -d 2 -c 4
# Cross Validation Accuracy =  88.89855072463766
# Cross Validation Error =  11.101449275362317
# Standard Deviation =  1.5119769687820264
# Empirical risk =  10.492753623188406
# Parameters:  -q -t 1 -d 2 -c 8
# Cross Validation Accuracy =  90.17391304347828
# Cross Validation Error =  9.82608695652174
# Standard Deviation =  1.4634093404480393
# Empirical risk =  9.246376811594203
# Parameters:  -q -t 1 -d 2 -c 16
# Cross Validation Accuracy =  91.47826086956522
# Cross Validation Error =  8.521739130434783
# Standard Deviation =  1.4562152680673006
# Empirical risk =  7.91304347826087
# Parameters:  -q -t 1 -d 2 -c 32
# Cross Validation Accuracy =  92.02898550724638
# Cross Validation Error =  7.971014492753623
# Standard Deviation =  1.3171672773915089
# Empirical risk =  7.246376811594203
# Parameters:  -q -t 1 -d 2 -c 64
# Cross Validation Accuracy =  92.46376811594203
# Cross Validation Error =  7.536231884057972
# Standard Deviation =  1.1594202898550723
# Empirical risk =  6.579710144927536
# Parameters:  -q -t 1 -d 2 -c 128
# Cross Validation Accuracy =  93.04347826086956
# Cross Validation Error =  6.956521739130435
# Standard Deviation =  1.0288834405390637
# Empirical risk =  6.260869565217392
# Parameters:  -q -t 1 -d 2 -c 256
# Cross Validation Accuracy =  93.33333333333333
# Cross Validation Error =  6.666666666666667
# Standard Deviation =  1.122603868465918
# Empirical risk =  5.768115942028985
# Parameters:  -q -t 1 -d 2 -c 512
# Cross Validation Accuracy =  93.42028985507247
# Cross Validation Error =  6.579710144927537
# Standard Deviation =  1.2965953186286985
# Empirical risk =  5.536231884057971
# Parameters:  -q -t 1 -d 2 -c 1024
# Cross Validation Accuracy =  93.68115942028986
# Cross Validation Error =  6.3188405797101455
# Standard Deviation =  1.364475628514762
# Empirical risk =  5.159420289855072
# Parameters:  -q -t 1 -d 2 -c 2048
# Cross Validation Accuracy =  93.91304347826086
# Cross Validation Error =  6.08695652173913
# Standard Deviation =  1.3961269076860632
# Empirical risk =  4.898550724637682
# Parameters:  -q -t 1 -d 2 -c 4096
# Cross Validation Accuracy =  94.02898550724638
# Cross Validation Error =  5.971014492753623
# Standard Deviation =  1.3483714028536822
# Empirical risk =  4.753623188405797
# Parameters:  -q -t 1 -d 2 -c 8192
# Cross Validation Accuracy =  93.82608695652173
# Cross Validation Error =  6.173913043478262
# Standard Deviation =  1.2094287562333372
# Empirical risk =  4.695652173913043
# Parameters:  -q -t 1 -d 2 -c 16384
# Cross Validation Accuracy =  93.76811594202898
# Cross Validation Error =  6.231884057971015
# Standard Deviation =  1.3486829129428222
# Empirical risk =  4.231884057971015
# Parameters:  -q -t 1 -d 2 -c 32768
# Cross Validation Accuracy =  93.59420289855073
# Cross Validation Error =  6.405797101449275
# Standard Deviation =  1.3623188405797104
# Empirical risk =  3.826086956521739
# Parameters:  -q -t 1 -d 2 -c 65536
# Cross Validation Accuracy =  93.44927536231884
# Cross Validation Error =  6.550724637681159
# Standard Deviation =  1.5457729421418414
# Empirical risk =  3.4202898550724634
# Parameters:  -q -t 1 -d 2 -c 131072
# Cross Validation Accuracy =  93.07246376811594
# Cross Validation Error =  6.927536231884058
# Standard Deviation =  1.4861963760341181
# Empirical risk =  3.246376811594203
# Parameters:  -q -t 1 -d 2 -c 262144
# Cross Validation Accuracy =  92.9855072463768
# Cross Validation Error =  7.014492753623189
# Standard Deviation =  1.2949743712283293
# Empirical risk =  2.6956521739130435
# Parameters:  -q -t 1 -d 2 -c 524288
# Cross Validation Accuracy =  92.55072463768116
# Cross Validation Error =  7.449275362318841
# Standard Deviation =  1.372150768526913
# Empirical risk =  2.3768115942028984
# Parameters:  -q -t 1 -d 2 -c 1048576
# Cross Validation Accuracy =  92.34782608695653
# Cross Validation Error =  7.6521739130434785
# Standard Deviation =  1.3607761848470146
# Empirical risk =  1.9420289855072466
# Parameters:  -q -t 1 -d 3 -c 9.5367431640625e-07
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 1.9073486328125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 3.814697265625e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 7.62939453125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 1.52587890625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 3.0517578125e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 6.103515625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 0.0001220703125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 0.000244140625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 0.00048828125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 0.0009765625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 0.001953125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 0.00390625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 0.0078125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 0.015625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 0.03125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 3 -c 0.0625
# Cross Validation Accuracy =  60.98550724637681
# Cross Validation Error =  39.014492753623195
# Standard Deviation =  2.625389420109971
# Empirical risk =  38.57971014492754
# Parameters:  -q -t 1 -d 3 -c 0.125
# Cross Validation Accuracy =  76.0
# Cross Validation Error =  24.000000000000004
# Standard Deviation =  3.0779278730338056
# Empirical risk =  21.44927536231884
# Parameters:  -q -t 1 -d 3 -c 0.25
# Cross Validation Accuracy =  82.1159420289855
# Cross Validation Error =  17.884057971014492
# Standard Deviation =  1.9097468301483058
# Empirical risk =  17.47826086956522
# Parameters:  -q -t 1 -d 3 -c 0.5
# Cross Validation Accuracy =  84.84057971014492
# Cross Validation Error =  15.159420289855072
# Standard Deviation =  2.074236598587228
# Empirical risk =  14.753623188405799
# Parameters:  -q -t 1 -d 3 -c 1
# Cross Validation Accuracy =  86.84057971014492
# Cross Validation Error =  13.159420289855072
# Standard Deviation =  1.5619934591660845
# Empirical risk =  12.782608695652172
# Parameters:  -q -t 1 -d 3 -c 2
# Cross Validation Accuracy =  88.28985507246375
# Cross Validation Error =  11.710144927536232
# Standard Deviation =  1.4734220321320386
# Empirical risk =  11.36231884057971
# Parameters:  -q -t 1 -d 3 -c 4
# Cross Validation Accuracy =  89.6231884057971
# Cross Validation Error =  10.376811594202897
# Standard Deviation =  1.4938085480261012
# Empirical risk =  9.826086956521738
# Parameters:  -q -t 1 -d 3 -c 8
# Cross Validation Accuracy =  91.10144927536233
# Cross Validation Error =  8.898550724637682
# Standard Deviation =  1.3030589445211027
# Empirical risk =  8.318840579710145
# Parameters:  -q -t 1 -d 3 -c 16
# Cross Validation Accuracy =  91.97101449275362
# Cross Validation Error =  8.028985507246379
# Standard Deviation =  1.2704120000470218
# Empirical risk =  7.420289855072464
# Parameters:  -q -t 1 -d 3 -c 32
# Cross Validation Accuracy =  92.43478260869566
# Cross Validation Error =  7.5652173913043494
# Standard Deviation =  1.0957135171846843
# Empirical risk =  6.9855072463768115
# Parameters:  -q -t 1 -d 3 -c 64
# Cross Validation Accuracy =  93.04347826086956
# Cross Validation Error =  6.9565217391304355
# Standard Deviation =  1.1300631124416194
# Empirical risk =  6.028985507246377
# Parameters:  -q -t 1 -d 3 -c 128
# Cross Validation Accuracy =  93.2463768115942
# Cross Validation Error =  6.753623188405797
# Standard Deviation =  1.1229780074093054
# Empirical risk =  5.739130434782608
# Parameters:  -q -t 1 -d 3 -c 256
# Cross Validation Accuracy =  93.3913043478261
# Cross Validation Error =  6.608695652173912
# Standard Deviation =  1.294974371228329
# Empirical risk =  5.36231884057971
# Parameters:  -q -t 1 -d 3 -c 512
# Cross Validation Accuracy =  93.73913043478261
# Cross Validation Error =  6.260869565217392
# Standard Deviation =  1.2514222112998785
# Empirical risk =  5.072463768115942
# Parameters:  -q -t 1 -d 3 -c 1024
# Cross Validation Accuracy =  94.0
# Cross Validation Error =  5.999999999999999
# Standard Deviation =  1.3411867015952785
# Empirical risk =  4.898550724637682
# Parameters:  -q -t 1 -d 3 -c 2048
# Cross Validation Accuracy =  93.88405797101449
# Cross Validation Error =  6.115942028985507
# Standard Deviation =  1.2796371046170503
# Empirical risk =  4.753623188405797
# Parameters:  -q -t 1 -d 3 -c 4096
# Cross Validation Accuracy =  93.76811594202897
# Cross Validation Error =  6.231884057971015
# Standard Deviation =  1.342438977032975
# Empirical risk =  4.579710144927536
# Parameters:  -q -t 1 -d 3 -c 8192
# Cross Validation Accuracy =  93.62318840579711
# Cross Validation Error =  6.3768115942028984
# Standard Deviation =  1.4258984204346483
# Empirical risk =  4.0
# Parameters:  -q -t 1 -d 3 -c 16384
# Cross Validation Accuracy =  93.47826086956522
# Cross Validation Error =  6.521739130434783
# Standard Deviation =  1.5406008424253113
# Empirical risk =  3.6231884057971016
# Parameters:  -q -t 1 -d 3 -c 32768
# Cross Validation Accuracy =  93.36231884057972
# Cross Validation Error =  6.637681159420291
# Standard Deviation =  1.5416911474750377
# Empirical risk =  3.3333333333333335
# Parameters:  -q -t 1 -d 3 -c 65536
# Cross Validation Accuracy =  92.95652173913042
# Cross Validation Error =  7.043478260869565
# Standard Deviation =  1.3964277646893801
# Empirical risk =  2.9275362318840576
# Parameters:  -q -t 1 -d 3 -c 131072
# Cross Validation Accuracy =  92.84057971014492
# Cross Validation Error =  7.159420289855072
# Standard Deviation =  1.4437576122217128
# Empirical risk =  2.3768115942028984
# Parameters:  -q -t 1 -d 3 -c 262144
# Cross Validation Accuracy =  92.17391304347827
# Cross Validation Error =  7.826086956521739
# Standard Deviation =  1.5116991084527882
# Empirical risk =  2.086956521739131
# Parameters:  -q -t 1 -d 3 -c 524288
# Cross Validation Accuracy =  91.3913043478261
# Cross Validation Error =  8.608695652173914
# Standard Deviation =  1.8288453976054908
# Empirical risk =  1.6231884057971016
# Parameters:  -q -t 1 -d 3 -c 1048576
# Cross Validation Accuracy =  91.68115942028984
# Cross Validation Error =  8.318840579710145
# Standard Deviation =  1.353657325082391
# Empirical risk =  1.652173913043478
# Parameters:  -q -t 1 -d 4 -c 9.5367431640625e-07
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 1.9073486328125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 3.814697265625e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 7.62939453125e-06
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 1.52587890625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 3.0517578125e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 6.103515625e-05
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 0.0001220703125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 0.000244140625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 0.00048828125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 0.0009765625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 0.001953125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 0.00390625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 0.0078125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 0.015625
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.27536231884058
# Parameters:  -q -t 1 -d 4 -c 0.03125
# Cross Validation Accuracy =  60.72463768115942
# Cross Validation Error =  39.27536231884058
# Standard Deviation =  2.6127183155536153
# Empirical risk =  39.2463768115942
# Parameters:  -q -t 1 -d 4 -c 0.0625
# Cross Validation Accuracy =  63.47826086956521
# Cross Validation Error =  36.52173913043478
# Standard Deviation =  2.6279482798013074
# Empirical risk =  33.130434782608695
# Parameters:  -q -t 1 -d 4 -c 0.125
# Cross Validation Accuracy =  80.1159420289855
# Cross Validation Error =  19.88405797101449
# Standard Deviation =  2.102997930112122
# Empirical risk =  19.159420289855074
# Parameters:  -q -t 1 -d 4 -c 0.25
# Cross Validation Accuracy =  83.04347826086958
# Cross Validation Error =  16.956521739130437
# Standard Deviation =  1.7306556798293544
# Empirical risk =  16.144927536231883
# Parameters:  -q -t 1 -d 4 -c 0.5
# Cross Validation Accuracy =  85.68115942028984
# Cross Validation Error =  14.318840579710145
# Standard Deviation =  1.9235547852796584
# Empirical risk =  14.057971014492754
# Parameters:  -q -t 1 -d 4 -c 1
# Cross Validation Accuracy =  87.27536231884059
# Cross Validation Error =  12.72463768115942
# Standard Deviation =  1.6623131546596719
# Empirical risk =  12.26086956521739
# Parameters:  -q -t 1 -d 4 -c 2
# Cross Validation Accuracy =  89.0144927536232
# Cross Validation Error =  10.98550724637681
# Standard Deviation =  1.4691392344897607
# Empirical risk =  10.492753623188406
# Parameters:  -q -t 1 -d 4 -c 4
# Cross Validation Accuracy =  90.11594202898551
# Cross Validation Error =  9.884057971014496
# Standard Deviation =  1.4805324972895226
# Empirical risk =  9.36231884057971
# Parameters:  -q -t 1 -d 4 -c 8
# Cross Validation Accuracy =  91.56521739130434
# Cross Validation Error =  8.434782608695652
# Standard Deviation =  1.4634093404480388
# Empirical risk =  7.82608695652174
# Parameters:  -q -t 1 -d 4 -c 16
# Cross Validation Accuracy =  92.28985507246378
# Cross Validation Error =  7.7101449275362315
# Standard Deviation =  1.1090508098382024
# Empirical risk =  7.159420289855073
# Parameters:  -q -t 1 -d 4 -c 32
# Cross Validation Accuracy =  92.8695652173913
# Cross Validation Error =  7.130434782608695
# Standard Deviation =  1.1240996770820475
# Empirical risk =  6.3768115942028984
# Parameters:  -q -t 1 -d 4 -c 64
# Cross Validation Accuracy =  93.2463768115942
# Cross Validation Error =  6.753623188405797
# Standard Deviation =  1.1884057971014492
# Empirical risk =  6.057971014492754
# Parameters:  -q -t 1 -d 4 -c 128
# Cross Validation Accuracy =  93.30434782608695
# Cross Validation Error =  6.695652173913044
# Standard Deviation =  1.2927016302016094
# Empirical risk =  5.333333333333334
# Parameters:  -q -t 1 -d 4 -c 256
# Cross Validation Accuracy =  93.59420289855072
# Cross Validation Error =  6.405797101449275
# Standard Deviation =  1.2730545655650867
# Empirical risk =  5.159420289855072
# Parameters:  -q -t 1 -d 4 -c 512
# Cross Validation Accuracy =  94.1159420289855
# Cross Validation Error =  5.884057971014493
# Standard Deviation =  1.341186701595278
# Empirical risk =  4.9275362318840585
# Parameters:  -q -t 1 -d 4 -c 1024
# Cross Validation Accuracy =  93.99999999999999
# Cross Validation Error =  6.0
# Standard Deviation =  1.296595318628698
# Empirical risk =  4.811594202898551
# Parameters:  -q -t 1 -d 4 -c 2048
# Cross Validation Accuracy =  93.82608695652173
# Cross Validation Error =  6.173913043478261
# Standard Deviation =  1.2571158517218228
# Empirical risk =  4.579710144927536
# Parameters:  -q -t 1 -d 4 -c 4096
# Cross Validation Accuracy =  93.59420289855072
# Cross Validation Error =  6.405797101449275
# Standard Deviation =  1.5471311472559441
# Empirical risk =  3.971014492753623
# Parameters:  -q -t 1 -d 4 -c 8192
# Cross Validation Accuracy =  93.47826086956522
# Cross Validation Error =  6.521739130434783
# Standard Deviation =  1.4332446742117233
# Empirical risk =  3.6521739130434785
# Parameters:  -q -t 1 -d 4 -c 16384
# Cross Validation Accuracy =  93.33333333333334
# Cross Validation Error =  6.666666666666667
# Standard Deviation =  1.528281313213225
# Empirical risk =  3.27536231884058
# Parameters:  -q -t 1 -d 4 -c 32768
# Cross Validation Accuracy =  92.95652173913044
# Cross Validation Error =  7.043478260869565
# Standard Deviation =  1.372150768526913
# Empirical risk =  3.0144927536231885
# Parameters:  -q -t 1 -d 4 -c 65536
# Cross Validation Accuracy =  92.78260869565216
# Cross Validation Error =  7.217391304347826
# Standard Deviation =  1.491838751589307
# Empirical risk =  2.3768115942028984
# Parameters:  -q -t 1 -d 4 -c 131072
# Cross Validation Accuracy =  92.3768115942029
# Cross Validation Error =  7.6231884057971016
# Standard Deviation =  1.3474364404834156
# Empirical risk =  1.971014492753623
# Parameters:  -q -t 1 -d 4 -c 262144
# Cross Validation Accuracy =  92.05797101449275
# Cross Validation Error =  7.942028985507245
# Standard Deviation =  1.4270763623294112
# Empirical risk =  1.652173913043478
# Parameters:  -q -t 1 -d 4 -c 524288
# Cross Validation Accuracy =  91.65217391304348
# Cross Validation Error =  8.347826086956522
# Standard Deviation =  1.5652173913043481
# Empirical risk =  1.4202898550724639
# Parameters:  -q -t 1 -d 4 -c 1048576
# Cross Validation Accuracy =  91.04347826086955
# Cross Validation Error =  8.956521739130435
# Standard Deviation =  1.508639267208476
# Empirical risk =  1.0724637681159421

# %%
for d_value in d_values:
    d_results = [(d, C, average_accuracy, average_error, sd, empirical_risk) for d, C, average_accuracy, average_error, sd, empirical_risk in k_fold_results if d == d_value]
    k_values = [math.log(d_result[1], 2) for d_result in d_results]
    error_values = [d_result[3] for d_result in d_results]
    error_values_with_sd = [d_result[3] + d_result[4] for d_result in d_results]
    error_values_without_sd = [d_result[3] - d_result[4] for d_result in d_results]

    print("d = ", d_value)
    plt.plot(C_values, error_values, 'b', label = "CV error")
    plt.plot(C_values, error_values_without_sd, 'r', label = "CV error - standard deviation") 
    plt.plot(C_values, error_values_with_sd, 'g', label = "CV error + standard deviation")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("С Value")
    plt.ylabel("Сross validation error +/- stadard deviation, %")
    plt.show()
    
    plt.plot(k_values, error_values, 'b', label = "CV error")
    plt.plot(k_values, error_values_without_sd, 'r', label = "CV error - standard deviation") 
    plt.plot(k_values, error_values_with_sd, 'g', label = "CV error + standard deviation")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel("log2C Value")
    plt.ylabel("Сross validation error +/- stadard deviation, %")
    plt.show()
    
    risks = [d_result[5] for d_result in d_results]
    
    plt.plot(C_values, risks, 'r')
    plt.xlabel("С Value")
    plt.ylabel("Empirical risk, %")
    plt.show()
    
    plt.plot(k_values, risks, 'r')
    plt.xlabel("log2C Value")
    plt.ylabel("Empirical risk, %")
    plt.show()
# Out:
# d =  1
# d =  2
# d =  3
# d =  4

# %%
best_params = min(k_fold_results, key=itemgetter(3))
print("Best params: ", best_params[:2])

test_y, test_x = svm_read_problem(test_scaled_converted_data_set_file_path)

true_risks = list()
cv_errors = list()
support_vectors = list()
for d in d_values:
    params_string = '-t 1 -d {0} -c {1}'.format(d, best_params[1])
    m = svm_train(y, x, params_string)
    
    support_vectors.append(len(m.get_SV()))
    
    p_label, p_acc, p_val = svm_predict(test_y, test_x, m, '-q')
    true_risk = p_acc[1] * 100
    true_risks.append(true_risk)
    
    cv_params_string = '-q -t 1 -d {0} -c {1} -v 10'.format(d, best_params[1])
    cv_error = 100 - svm_train(y, x, cv_params_string)
    cv_errors.append(cv_error)
    
# Drawing plot with error on test sample vs. cross validation error
plt.plot(d_values, true_risks, 'r', label = "Error on test sample")
plt.plot(d_values, cv_errors, 'g', label = "Error on cross validation")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel("d Value")
plt.ylabel("True risk, %")
plt.show()

print("Support verctors count: ", support_vectors)
# Drawing plot with support vectors count
plt.plot(d_values, support_vectors, 'r')
plt.xlabel("d Value")
plt.ylabel("Support vectors amount")
plt.show()
# Out:
# Best params:  (4, 512)
# Cross Validation Accuracy = 93.1884%
# Cross Validation Accuracy = 93.5362%
# Cross Validation Accuracy = 93.7971%
# Cross Validation Accuracy = 94.029%
# Support verctors count:  [776, 724, 691, 676]
